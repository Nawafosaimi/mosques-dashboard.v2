# %%
# Out:
# hello

# %%
import pandas as pd

# %%
df = pd.read_parquet(r"D:\energy\mosques\mosque_violations_by_day.parquet")

# %%
df.head(5)
# Out:
#            METER_ID        date   Period  avg_power  readings  Violated
# 0  AEC2020720007045  2025-01-02  Evening   0.594000         7     False
# 1  AEC2020720007045  2025-01-02  Morning   0.195750         8     False
# 2  AEC2020720007045  2025-01-04  Evening   0.709429         7     False
# 3  AEC2020720007045  2025-01-04  Morning   0.179750         8     False
# 4  AEC2020720007045  2025-01-06  Evening   0.673714         7     False

# %%
dfin = pd.read_parquet(r"D:\energy\mosques\Industry Code with Population 1.parquet")
dfin.head(5)
# Out:
#        Meter Number     Premise  Installation  Contract Account  \
# 0  ECC2020811088044  4000140860    5000121817       10001335779
# 1  KFM2020660192535  4000542532    5000545847       10005466189
# 2  KFM2020660202496  4000536241    5000526091       10005534814
# 3  KFM2020660200537  4000542039    5000545076       10005545175
# 4  KFM2020660047193  4000548963    5000544928       10005563093
#
#    X Coordinates  Y Coordinates Industry Sector  Business Partner  \
# 0      50.160867      26.180090          Mosque         100132272
# 1      46.699344      24.556046          Mosque         100558961
# 2      46.536884      24.569203          Mosque         100565478
# 3      46.668627      24.519298          Mosque         100563191
# 4      46.536076      24.560797          Mosque         100571224
#
#                                    Name Multiplication Factor  ... Department  \
# 0   وزارة الشؤن الاسلامية/مسجد بورتبل .               1.00000  ...       3100
# ...

# %%
dfin.columns
# Out:
# Index(['Meter Number', 'Premise', 'Installation', 'Contract Account',
#        'X Coordinates', 'Y Coordinates', 'Industry Sector', 'Business Partner',
#        'Name', 'Multiplication Factor', 'Device Type', 'Region', 'Department',
#        'Department Name', 'Office', 'Office Name', 'Province', 'POPULATION',
#        'HARA_NAME', 'PLACE_NAME', 'GOVERNORATE_NAME_AR', 'Shape_Area'],
#       dtype='object')
