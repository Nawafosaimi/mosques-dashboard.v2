# %%
# Out:
# hello

# %%
import pandas as pd

# %%
df = pd.read_parquet(r"C:\Users\AlosaiNK\OneDrive - Ministry of Energy\Documents\dashboard v2\latest ver\mosques-dashboard.v2\mosques\mosque_violations_by_day.parquet")

# %%
df.head(10)
# Out:
#            METER_ID        date   Period  avg_power  readings  Violated
# 0  AEC2020720007045  2025-01-02  Evening   0.594000         7     False
# 1  AEC2020720007045  2025-01-02  Morning   0.195750         8     False
# 2  AEC2020720007045  2025-01-04  Evening   0.709429         7     False
# 3  AEC2020720007045  2025-01-04  Morning   0.179750         8     False
# 4  AEC2020720007045  2025-01-06  Evening   0.673714         7     False
# 5  AEC2020720007045  2025-01-06  Morning   0.165778         9     False
# 6  AEC2020720007045  2025-01-07  Evening   0.749714         7     False
# 7  AEC2020720007045  2025-01-07  Morning   0.267111         9     False
# 8  AEC2020720007045  2025-01-09  Evening   0.523429         7     False
# 9  AEC2020720007045  2025-01-09  Morning   0.166000         9     False
